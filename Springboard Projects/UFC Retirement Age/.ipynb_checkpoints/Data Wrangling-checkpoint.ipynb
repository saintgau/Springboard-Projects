# %% [markdown]
# # UFC Retirement Age - Data Wrangling<a id='2_Data_wrangling'></a>

# %% [markdown]
# ## 1. Contents<a id='1_Contents'></a>
# * [1 Contents](#_UFC_Retirement_Age_-_Data_Wrangling)
# * [2 Data Collection](#_UFC_Retirement_Age_-_Data_Wrangling)
# * [3 Data Organization](#_UFC_Retirement_Age_-_Data_Wrangling)
# * [4_Data Definition](#_UFC_Retirement_Age_-_Data_Wrangling)
# * [5_Data Cleaning](#_UFC_Retirement_Age_-_Data_Wrangling)
#  * [5.1 Remove unnecessary columns](#_UFC_Retirement_Age_-_Data_Wrangling)
#  * [5.2 Transform DataFrame](#_UFC_Retirement_Age_-_Data_Wrangling)
#  * [5.3_Remove_Null_Values](#_UFC_Retirement_Age_-_Data_Wrangling)

# %% [markdown]
# ## 2. Data Collection<a id='2.2_Introduction'></a>

# %% [markdown]
# **Goal: Organize your data to streamline the next steps of your capstone.**
#
# First, all libraries required for this project will be imported.

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
import kaggle as kg
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
from zipfile import ZipFile

# %% [markdown]
# Using the Kaggle API, the necessary dataset is imported as a Pandas DataFrame and previewed.

# %%
api = KaggleApi()
api.authenticate()
api.dataset_download_file('mdabbert/ultimate-ufc-dataset', 'ufc-master.csv')
zf = ZipFile('ufc-master.csv.zip')
zf.extractall()
zf.close()
ufc = pd.read_csv('ufc-master.csv')
ufc.head()
# Out:
#          R_fighter           B_fighter  R_odds  B_odds       R_ev   B_ev  \
# 0  Colby Covington       Tyron Woodley    -335     260  29.850746  260.0
# 1  Khamzat Chimaev  Gerald Meerschaert    -400     300  25.000000  300.0
# 2    Johnny Walker          Ryan Spann    -125     100  80.000000  100.0
# 3   Mackenzie Dern        Randa Markos    -177     140  56.497175  140.0
# 4    Kevin Holland      Darren Stewart    -265     205  37.735849  205.0
#
#         date                location country Winner  ...  R_td_attempted_bout  \
# 0  9/19/2020  Las Vegas, Nevada, USA     USA    Red  ...                  NaN
# 1  9/19/2020  Las Vegas, Nevada, USA     USA    Red  ...                  NaN
# 2  9/19/2020  Las Vegas, Nevada, USA     USA    Red  ...                  NaN
# 3  9/19/2020  Las Vegas, Nevada, USA     USA    Red  ...                  NaN
# 4  9/19/2020  Las Vegas, Nevada, USA     USA    Red  ...                  NaN
#
#   B_td_attempted_bout R_td_pct_bout  B_td_pct_bout  R_sub_attempts_bout  \
# 0                 NaN           NaN            NaN                  NaN
# 1                 NaN           NaN            NaN                  NaN
# 2                 NaN           NaN            NaN                  NaN
# 3                 NaN           NaN            NaN                  NaN
# 4                 NaN           NaN            NaN                  NaN
#
#    B_sub_attempts_bout  R_pass_bout  B_pass_bout  R_rev_bout  B_rev_bout
# 0                  NaN          NaN          NaN         NaN         NaN
# 1                  NaN          NaN          NaN         NaN         NaN
# 2                  NaN          NaN          NaN         NaN         NaN
# 3                  NaN          NaN          NaN         NaN         NaN
# 4                  NaN          NaN          NaN         NaN         NaN
#
# [5 rows x 137 columns]

# %%
ufc.shape
# Out:
# (4387, 137)

# %% [markdown]
# ## 3. Data Organization<a id='2.2_Introduction'></a>

# %% [markdown]
# **Goal: Create a file structure and add your work to the GitHub repository you’ve created for this project.**
#
# This notebook, along with the rest of the notebooks for this capstone project, will be uploaded to GitHub in a proper repository.

# %% [markdown]
# ## 4. Data Definition<a id='2.2_Introduction'></a>

# %% [markdown]
# **Goal: Gain an understanding of your data features to inform the next steps of your project.**
#
# To begin cleaning up my data, I will first examine the columns in the dataset.

# %%
ufc.dtypes
# Out:
# R_fighter               object
# B_fighter               object
# R_odds                   int64
# B_odds                   int64
# R_ev                   float64
#                         ...
# B_sub_attempts_bout    float64
# R_pass_bout            float64
# B_pass_bout            float64
# R_rev_bout             float64
# B_rev_bout             float64
# Length: 137, dtype: object

# %% [markdown]
# Since there are a lot of columns, I will check the columns that belong to each data type. Even though I won't be able to examine every single column, hopefully the columns will have the appropriate data type at a glance.

# %%
ufc.dtypes[ufc.dtypes == object]
# Out:
# R_fighter            object
# B_fighter            object
# date                 object
# location             object
# country              object
# Winner               object
# weight_class         object
# gender               object
# B_Stance             object
# R_Stance             object
# better_rank          object
# finish               object
# finish_details       object
# finish_round_time    object
# dtype: object

# %%
ufc.dtypes[ufc.dtypes == 'float64']
# Out:
# R_ev                    float64
# B_ev                    float64
# B_avg_SIG_STR_landed    float64
# B_avg_SIG_STR_pct       float64
# B_avg_SUB_ATT           float64
#                          ...
# B_sub_attempts_bout     float64
# R_pass_bout             float64
# B_pass_bout             float64
# R_rev_bout              float64
# B_rev_bout              float64
# Length: 75, dtype: object

# %%
ufc.dtypes[(ufc.dtypes != 'object') & (ufc.dtypes != 'float64')]
# Out:
# R_odds                          int64
# B_odds                          int64
# title_bout                       bool
# no_of_rounds                    int64
# B_current_lose_streak           int64
# B_current_win_streak            int64
# B_draw                          int64
# B_longest_win_streak            int64
# B_losses                        int64
# B_total_rounds_fought           int64
# B_total_title_bouts             int64
# B_win_by_Decision_Majority      int64
# B_win_by_Decision_Split         int64
# B_win_by_Decision_Unanimous     int64
# B_win_by_KO/TKO                 int64
# B_win_by_Submission             int64
# B_win_by_TKO_Doctor_Stoppage    int64
# B_wins                          int64
# B_Weight_lbs                    int64
# R_current_lose_streak           int64
# R_current_win_streak            int64
# R_draw                          int64
# R_longest_win_streak            int64
# R_losses                        int64
# R_total_rounds_fought           int64
# R_total_title_bouts             int64
# R_win_by_Decision_Majority      int64
# R_win_by_Decision_Split         int64
# R_win_by_Decision_Unanimous     int64
# R_win_by_KO/TKO                 int64
# R_win_by_Submission             int64
# R_win_by_TKO_Doctor_Stoppage    int64
# R_wins                          int64
# R_Weight_lbs                    int64
# R_age                           int64
# B_age                           int64
# lose_streak_dif                 int64
# win_streak_dif                  int64
# longest_win_streak_dif          int64
# win_dif                         int64
# loss_dif                        int64
# total_round_dif                 int64
# total_title_bout_dif            int64
# ko_dif                          int64
# sub_dif                         int64
# age_dif                         int64
# empty_arena                     int64
# constant_1                      int64
# dtype: object

# %% [markdown]
# With all the datatypes accounted for, it looks like each column has the proper datatype for its data. If this is not the case, it can be dealt with later on. Each column has also been properly named. As of now, there are no more major changes that need to be made for this step.

# %% [markdown]
# ## 5. Data Cleaning<a id='2.2_Introduction'></a>

# %% [markdown]
# **Goal: Clean up the data in order to prepare it for the next steps of your project.**

# %% [markdown]
# ### 5.1 Remove unnecessary columns

# %% [markdown]
# There are several columns in this dataset that will most likely not be needed for this project. Those will first be preserved in a separate DataFrame, then removed from the main one. For example, the location and referee for each fight will likely not be relevant to this analysis.

# %%
del_col_names = ['location']
ufc_del = ufc[del_col_names]
ufc.drop(ufc_del, axis=1, inplace=True)
pd.Series(['Referee', 'location']).isin(ufc.columns).all()
# Out:
# False

# %% [markdown]
# ### 5.2 Transform DataFrame

# %% [markdown]
# Next, it's time to find any Null values and decide whether to drop them or impute them. I begin this task by setting the index for this DataFrame.

# %%
ufc = ufc.set_index(['date'], drop=True)

# %% [markdown]
# Then, I will check the amount of NaN values in the dataset.

# %%
ufc.isnull().sum().sum()
# Out:
# 166997

# %%
null_rows = ufc.isnull().sum(axis=1)
null_rows = null_rows[null_rows > 0].sort_values(ascending=False)
print('Rows with at least one Null value:', str(null_rows.count()))
# Out:
# Rows with at least one Null value: 4387

# %%
null_cols = ufc.isnull().sum(axis=0)
null_cols = null_cols[null_cols > 0].sort_values(ascending=False)
print('Columns with at least one Null value:', str(null_cols.count()))
# Out:
# Columns with at least one Null value: 67

# %% [markdown]
# There seem to be a lot of Null values, so inspecing the distribution of Null values may shed some light on this problem.

# %%
null_rows.head()
# Out:
# date
# 11/8/2014     67
# 5/24/2014     67
# 12/12/2014    67
# 7/26/2014     67
# 11/7/2015     67
# dtype: int64

# %% [markdown]
# It seems like most of the Null values might have been the result of insufficient information during the earlier days of the UFC, also known as the UFC's "Dark Ages." To verify this, I will plot the distribution of Null values in the DataFrame sorted by date.

# %%
msno.matrix(ufc.sort_values(by='date'))

# %% [markdown]
# The Null values seem to be distributed more evenly than I thought they were when sorted by date. However, the Null values are disproportionately distributed between the Red and Blue corner fighters. Since it would make the exploratory analysis simpler, I will transform the DataFrame so that each row corresponds to one fighter instead of one fight. This way, I will have less columns, but more rows. This will also make it easier to remove rows with missing data for one fighter without removing data for the other fighter as well. I will do this by creating 2 DataFrames, one for Red fighters and one for Blue fighters, then merging them.

# %%
ufc.drop(columns = [null_cols.head(28).index[n] for n in range(28)], inplace=True)

# %%
ufc.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_odds', 'B_odds', 'R_ev', 'B_ev', 'country',
#        'Winner', 'title_bout', 'weight_class',
#        ...
#        'R_td_attempted_bout', 'B_td_attempted_bout', 'R_td_pct_bout',
#        'B_td_pct_bout', 'R_sub_attempts_bout', 'B_sub_attempts_bout',
#        'R_pass_bout', 'B_pass_bout', 'R_rev_bout', 'B_rev_bout'],
#       dtype='object', length=107)

# %%
red_cols = [col for col in ufc.columns if not col.startswith('B')]
red_fighters = ufc[red_cols]
red_fighters.head()
# Out:
#                  R_fighter  R_odds       R_ev country Winner  title_bout  \
# date
# 9/19/2020  Colby Covington    -335  29.850746     USA    Red       False
# 9/19/2020  Khamzat Chimaev    -400  25.000000     USA    Red       False
# 9/19/2020    Johnny Walker    -125  80.000000     USA    Red       False
# 9/19/2020   Mackenzie Dern    -177  56.497175     USA    Red       False
# 9/19/2020    Kevin Holland    -265  37.735849     USA    Red       False
#
#                   weight_class  gender  no_of_rounds  R_current_lose_streak  \
# date
# 9/19/2020         Welterweight    MALE             5                      1
# 9/19/2020         Middleweight    MALE             3                      0
# 9/19/2020    Light Heavyweight    MALE             3                      2
# 9/19/2020  Women's Strawweight  FEMALE             3                      0
# 9/19/2020         Middleweight    MALE             3                      0
#
#            ...  R_sig_str_attempted_bout  R_sig_str_pct_bout  \
# date       ...
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
#
#            R_tot_str_landed_bout  R_tot_str_attempted_bout  R_td_landed_bout  \
# date
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
#
#            R_td_attempted_bout  R_td_pct_bout  R_sub_attempts_bout  \
# date
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
#
#            R_pass_bout  R_rev_bout
# date
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
#
# [5 rows x 68 columns]

# %%
blue_cols = [col for col in ufc.columns if not col.startswith('R')]
blue_fighters = ufc[blue_cols]
blue_fighters.head()
# Out:
#                     B_fighter  B_odds   B_ev country Winner  title_bout  \
# date
# 9/19/2020       Tyron Woodley     260  260.0     USA    Red       False
# 9/19/2020  Gerald Meerschaert     300  300.0     USA    Red       False
# 9/19/2020          Ryan Spann     100  100.0     USA    Red       False
# 9/19/2020        Randa Markos     140  140.0     USA    Red       False
# 9/19/2020      Darren Stewart     205  205.0     USA    Red       False
#
#                   weight_class  gender  no_of_rounds  B_current_lose_streak  \
# date
# 9/19/2020         Welterweight    MALE             5                      2
# 9/19/2020         Middleweight    MALE             3                      1
# 9/19/2020    Light Heavyweight    MALE             3                      0
# 9/19/2020  Women's Strawweight  FEMALE             3                      1
# 9/19/2020         Middleweight    MALE             3                      0
#
#            ...  B_sig_str_attempted_bout  B_sig_str_pct_bout  \
# date       ...
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
#
#            B_tot_str_landed_bout  B_tot_str_attempted_bout  B_td_landed_bout  \
# date
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
#
#            B_td_attempted_bout  B_td_pct_bout  B_sub_attempts_bout  \
# date
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
#
#            B_pass_bout  B_rev_bout
# date
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
#
# [5 rows x 68 columns]

# %%
neutral_cols = [col[2:]  if col.startswith('R') else col for col in red_fighters.columns ]
neutral_cols
# Out:
# ['fighter',
#  'odds',
#  'ev',
#  'country',
#  'Winner',
#  'title_bout',
#  'weight_class',
#  'gender',
#  'no_of_rounds',
#  'current_lose_streak',
#  'current_win_streak',
#  'draw',
#  'avg_SIG_STR_landed',
#  'avg_SIG_STR_pct',
#  'avg_SUB_ATT',
#  'avg_TD_landed',
#  'avg_TD_pct',
#  'longest_win_streak',
#  'losses',
#  'total_rounds_fought',
#  'total_title_bouts',
#  'win_by_Decision_Majority',
#  'win_by_Decision_Split',
#  'win_by_Decision_Unanimous',
#  'win_by_KO/TKO',
#  'win_by_Submission',
#  'win_by_TKO_Doctor_Stoppage',
#  'wins',
#  'Stance',
#  'Height_cms',
#  'Reach_cms',
#  'Weight_lbs',
#  'age',
#  'lose_streak_dif',
#  'win_streak_dif',
#  'longest_win_streak_dif',
#  'win_dif',
#  'loss_dif',
#  'total_round_dif',
#  'total_title_bout_dif',
#  'ko_dif',
#  'sub_dif',
#  'height_dif',
#  'reach_dif',
#  'age_dif',
#  'sig_str_dif',
#  'avg_sub_att_dif',
#  'avg_td_dif',
#  'empty_arena',
#  'constant_1',
#  'better_rank',
#  'finish',
#  'finish_details',
#  'finish_round',
#  'finish_round_time',
#  'total_fight_time_secs',
#  'kd_bout',
#  'sig_str_landed_bout',
#  'sig_str_attempted_bout',
#  'sig_str_pct_bout',
#  'tot_str_landed_bout',
#  'tot_str_attempted_bout',
#  'td_landed_bout',
#  'td_attempted_bout',
#  'td_pct_bout',
#  'sub_attempts_bout',
#  'pass_bout',
#  'rev_bout']

# %% [markdown]
# I will merge the 2 DataFrames with these neutral columns, but first I have to change the values in the Winner columns. This will help me in my analysis later on.

# %%
red_fighters['Winner'] = [winner == 'Red' for winner in red_fighters['Winner']]
red_fighters.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  R_fighter  R_odds       R_ev country  Winner  title_bout  \
# date
# 9/19/2020  Colby Covington    -335  29.850746     USA    True       False
# 9/19/2020  Khamzat Chimaev    -400  25.000000     USA    True       False
# 9/19/2020    Johnny Walker    -125  80.000000     USA    True       False
# 9/19/2020   Mackenzie Dern    -177  56.497175     USA    True       False
# 9/19/2020    Kevin Holland    -265  37.735849     USA    True       False
#
#                   weight_class  gender  no_of_rounds  R_current_lose_streak  \
# date
# 9/19/2020         Welterweight    MALE             5                      1
# 9/19/2020         Middleweight    MALE             3                      0
# 9/19/2020    Light Heavyweight    MALE             3                      2
# 9/19/2020  Women's Strawweight  FEMALE             3                      0
# 9/19/2020         Middleweight    MALE             3                      0
#
#            ...  R_sig_str_attempted_bout  R_sig_str_pct_bout  \
# date       ...
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
#
#            R_tot_str_landed_bout  R_tot_str_attempted_bout  R_td_landed_bout  \
# date
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
#
#            R_td_attempted_bout  R_td_pct_bout  R_sub_attempts_bout  \
# date
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
#
#            R_pass_bout  R_rev_bout
# date
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
#
# [5 rows x 68 columns]

# %%
red_fighters['better_rank'] = [value == 'Red' for value in red_fighters['better_rank']]
red_fighters['better_rank'].value_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# False    3228
# True     1159
# Name: better_rank, dtype: int64

# %%
blue_fighters['Winner'] = [winner == 'Blue' for winner in blue_fighters['Winner']]
blue_fighters.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     B_fighter  B_odds   B_ev country  Winner  title_bout  \
# date
# 9/19/2020       Tyron Woodley     260  260.0     USA   False       False
# 9/19/2020  Gerald Meerschaert     300  300.0     USA   False       False
# 9/19/2020          Ryan Spann     100  100.0     USA   False       False
# 9/19/2020        Randa Markos     140  140.0     USA   False       False
# 9/19/2020      Darren Stewart     205  205.0     USA   False       False
#
#                   weight_class  gender  no_of_rounds  B_current_lose_streak  \
# date
# 9/19/2020         Welterweight    MALE             5                      2
# 9/19/2020         Middleweight    MALE             3                      1
# 9/19/2020    Light Heavyweight    MALE             3                      0
# 9/19/2020  Women's Strawweight  FEMALE             3                      1
# 9/19/2020         Middleweight    MALE             3                      0
#
#            ...  B_sig_str_attempted_bout  B_sig_str_pct_bout  \
# date       ...
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
# 9/19/2020  ...                       NaN                 NaN
#
#            B_tot_str_landed_bout  B_tot_str_attempted_bout  B_td_landed_bout  \
# date
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
# 9/19/2020                    NaN                       NaN               NaN
#
#            B_td_attempted_bout  B_td_pct_bout  B_sub_attempts_bout  \
# date
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
# 9/19/2020                  NaN            NaN                  NaN
#
#            B_pass_bout  B_rev_bout
# date
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
# 9/19/2020          NaN         NaN
#
# [5 rows x 68 columns]

# %%
blue_fighters['better_rank'] = [rank == 'Blue' for rank in blue_fighters['better_rank']]
blue_fighters['better_rank'].head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# date
# 9/19/2020    False
# 9/19/2020    False
# 9/19/2020    False
# 9/19/2020    False
# 9/19/2020    False
# Name: better_rank, dtype: bool

# %%
blue_fighters['better_rank'].value_counts()
# Out:
# False    4317
# True       70
# Name: better_rank, dtype: int64

# %%
red_fighters.columns = neutral_cols
blue_fighters.columns = neutral_cols
red_fighters.reset_index(inplace=True)
blue_fighters.reset_index(inplace=True)

# %%
red_fighters.set_index(pd.Index([number * 2 for number in red_fighters.index]), inplace=True)
red_fighters.head()
# Out:
#         date          fighter  odds         ev country  Winner  title_bout  \
# 0  9/19/2020  Colby Covington  -335  29.850746     USA    True       False
# 2  9/19/2020  Khamzat Chimaev  -400  25.000000     USA    True       False
# 4  9/19/2020    Johnny Walker  -125  80.000000     USA    True       False
# 6  9/19/2020   Mackenzie Dern  -177  56.497175     USA    True       False
# 8  9/19/2020    Kevin Holland  -265  37.735849     USA    True       False
#
#           weight_class  gender  no_of_rounds  ...  sig_str_attempted_bout  \
# 0         Welterweight    MALE             5  ...                     NaN
# 2         Middleweight    MALE             3  ...                     NaN
# 4    Light Heavyweight    MALE             3  ...                     NaN
# 6  Women's Strawweight  FEMALE             3  ...                     NaN
# 8         Middleweight    MALE             3  ...                     NaN
#
#    sig_str_pct_bout  tot_str_landed_bout  tot_str_attempted_bout  \
# 0               NaN                  NaN                     NaN
# 2               NaN                  NaN                     NaN
# 4               NaN                  NaN                     NaN
# 6               NaN                  NaN                     NaN
# 8               NaN                  NaN                     NaN
#
#    td_landed_bout  td_attempted_bout  td_pct_bout  sub_attempts_bout  \
# 0             NaN                NaN          NaN                NaN
# 2             NaN                NaN          NaN                NaN
# 4             NaN                NaN          NaN                NaN
# 6             NaN                NaN          NaN                NaN
# 8             NaN                NaN          NaN                NaN
#
#    pass_bout  rev_bout
# 0        NaN       NaN
# 2        NaN       NaN
# 4        NaN       NaN
# 6        NaN       NaN
# 8        NaN       NaN
#
# [5 rows x 69 columns]

# %%
blue_fighters.set_index(pd.Index([number*2+1 for number in blue_fighters.index]), inplace=True)
blue_fighters.head()
# Out:
#         date             fighter  odds     ev country  Winner  title_bout  \
# 1  9/19/2020       Tyron Woodley   260  260.0     USA   False       False
# 3  9/19/2020  Gerald Meerschaert   300  300.0     USA   False       False
# 5  9/19/2020          Ryan Spann   100  100.0     USA   False       False
# 7  9/19/2020        Randa Markos   140  140.0     USA   False       False
# 9  9/19/2020      Darren Stewart   205  205.0     USA   False       False
#
#           weight_class  gender  no_of_rounds  ...  sig_str_attempted_bout  \
# 1         Welterweight    MALE             5  ...                     NaN
# 3         Middleweight    MALE             3  ...                     NaN
# 5    Light Heavyweight    MALE             3  ...                     NaN
# 7  Women's Strawweight  FEMALE             3  ...                     NaN
# 9         Middleweight    MALE             3  ...                     NaN
#
#    sig_str_pct_bout  tot_str_landed_bout  tot_str_attempted_bout  \
# 1               NaN                  NaN                     NaN
# 3               NaN                  NaN                     NaN
# 5               NaN                  NaN                     NaN
# 7               NaN                  NaN                     NaN
# 9               NaN                  NaN                     NaN
#
#    td_landed_bout  td_attempted_bout  td_pct_bout  sub_attempts_bout  \
# 1             NaN                NaN          NaN                NaN
# 3             NaN                NaN          NaN                NaN
# 5             NaN                NaN          NaN                NaN
# 7             NaN                NaN          NaN                NaN
# 9             NaN                NaN          NaN                NaN
#
#    pass_bout  rev_bout
# 1        NaN       NaN
# 3        NaN       NaN
# 5        NaN       NaN
# 7        NaN       NaN
# 9        NaN       NaN
#
# [5 rows x 69 columns]

# %%
df = pd.concat([red_fighters, blue_fighters]).sort_index()
df.head()
# Out:
#         date             fighter  odds          ev country  Winner  \
# 0  9/19/2020     Colby Covington  -335   29.850746     USA    True
# 1  9/19/2020       Tyron Woodley   260  260.000000     USA   False
# 2  9/19/2020     Khamzat Chimaev  -400   25.000000     USA    True
# 3  9/19/2020  Gerald Meerschaert   300  300.000000     USA   False
# 4  9/19/2020       Johnny Walker  -125   80.000000     USA    True
#
#    title_bout       weight_class gender  no_of_rounds  ...  \
# 0       False       Welterweight   MALE             5  ...
# 1       False       Welterweight   MALE             5  ...
# 2       False       Middleweight   MALE             3  ...
# 3       False       Middleweight   MALE             3  ...
# 4       False  Light Heavyweight   MALE             3  ...
#
#    sig_str_attempted_bout  sig_str_pct_bout  tot_str_landed_bout  \
# 0                     NaN               NaN                  NaN
# 1                     NaN               NaN                  NaN
# 2                     NaN               NaN                  NaN
# 3                     NaN               NaN                  NaN
# 4                     NaN               NaN                  NaN
#
#    tot_str_attempted_bout  td_landed_bout  td_attempted_bout  td_pct_bout  \
# 0                     NaN             NaN                NaN          NaN
# 1                     NaN             NaN                NaN          NaN
# 2                     NaN             NaN                NaN          NaN
# 3                     NaN             NaN                NaN          NaN
# 4                     NaN             NaN                NaN          NaN
#
#    sub_attempts_bout  pass_bout  rev_bout
# 0                NaN        NaN       NaN
# 1                NaN        NaN       NaN
# 2                NaN        NaN       NaN
# 3                NaN        NaN       NaN
# 4                NaN        NaN       NaN
#
# [5 rows x 69 columns]

# %% [markdown]
# ### 5.2 Remove Null Values

# %% [markdown]
# Now that each row represents one fighter, removing one row for not having a fighter's age would not involve collateral removal of another fighter's data. Since age is the most pertinent variable, I will remove rows missing the fighter's age.

# %%
df.dropna(subset=['age'], inplace=True)
df.shape
# Out:
# (8774, 69)

# %% [markdown]
# The rest of the DataFrame now contains at least the fighter's name, whether they won the fight on a certain date, and their age. This should be enough to keep the rest of the DataFrame. I will need to create separate DataFrames with no Null values when I conduct further analysis on other fight performance metrics.

# %%
df.to_csv('df.csv')
